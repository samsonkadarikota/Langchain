# %% [markdown]
# #**This Notebook Shows How to use Agents to Interact with Pandas DataFrame**

# %% [markdown]
# #**In LangChain, the Agent can access many dataframes at once**

# %% [markdown]
# #**Step 01: Install All the Required Packages**

# %%
# %pip install langchain
# %pip install watermark
# %pip install google-generativeai
# %pip install langchain-experimental
# %pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #Step 02: import all the required libraries

# %%
import os
import warnings
import pandas as pd
warnings.filterwarnings("ignore")

# %%
from langchain_experimental.agents import create_pandas_dataframe_agent
from langchain.llms import OpenAI

# %%
from langchain.agents import initialize_agent
from langchain.llms import OpenAI

# %%
from langchain.agents import initialize_agent
from langchain.llms import OpenAI
import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# #Step 03: Setup the Environment

# %%
os.environ["OPENAI_API_KEY"] = "OpenAI_API_Key"

# %% [markdown]
# #Step 04: Visualize the Data

# %%
#url = "https://raw.githubusercontent.com/sudarshan-koirala/Logistic-Regression-for-Titanic-Dataset/master/Train_Titanic.csv"
df=pd.read_csv(r'D:\Samson - All Data\Naresh IT Institute\Full stack data science course\10th September classes\8th, 9th, 10th-  LLM Introduction, OPEN AI PROJECT\Langchain Agents\titanic dataset.csv')
print(df.shape)
df.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# #Step 05: Single DataFrame Example

# %% [markdown]
# #Agent can interact with Single DataFrame

# %%
llm=OpenAI()

# %%
from langchain.chat_models import ChatOpenAI

# %%
llm = ChatOpenAI(temperature=0, model="gpt-3.5-turbo")

# %%
agent = create_pandas_dataframe_agent(
    llm,
    df,
    verbose=True,
    agent_type="openai-tools",   # or "zero-shot-reat-description
    allow_dangerous_code=True  # This is the critical fix
)

# %%
agent.run("How many rows are there")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 agent.run("How many rows are there")
#
# File c:\Users\samua\anaconda3\envs\tensorflow_env\lib\site-packages\langchain_core\_api\deprecation.py:193, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     191     warned = True
#     192     emit_warning()
# --> 193 return wrapped(*args, **kwargs)
#
# File c:\Users\samua\anaconda3\envs\tensorflow_env\lib\site-packages\langchain\chains\base.py:627, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     625         msg = "`run` supports only one positional argument."
#     626         raise ValueError(msg)
# --> 627     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     628         _output_key
#     629     ]
# ...

# %%
agent.run("How many people have more than 3 siblings")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 agent.run("How many people have more than 3 siblings")
#
# File c:\Users\samua\anaconda3\envs\tensorflow_env\lib\site-packages\langchain_core\_api\deprecation.py:193, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     191     warned = True
#     192     emit_warning()
# --> 193 return wrapped(*args, **kwargs)
#
# File c:\Users\samua\anaconda3\envs\tensorflow_env\lib\site-packages\langchain\chains\base.py:627, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     625         msg = "`run` supports only one positional argument."
#     626         raise ValueError(msg)
# --> 627     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     628         _output_key
#     629     ]
# ...

# %% [markdown]
# #**Step 06: Multi DataFrame Example**

# %% [markdown]
# #**Agent can also interact with Multiple DataFrames passed in a list**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df1=df.copy()

# %%
df1["Age"] = df1["Age"].fillna(df1["Age"].mean())

# %%
agent=create_pandas_dataframe_agent(llm, [df, df1], verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 agent=create_pandas_dataframe_agent(llm, [df, df1], verbose=True)
#
# File c:\Users\samua\anaconda3\envs\tensorflow_env\lib\site-packages\langchain_experimental\agents\agent_toolkits\pandas\base.py:249, in create_pandas_dataframe_agent(llm, df, agent_type, callback_manager, prefix, suffix, input_variables, verbose, return_intermediate_steps, max_iterations, max_execution_time, early_stopping_method, agent_executor_kwargs, include_df_in_prompt, number_of_head_rows, extra_tools, engine, allow_dangerous_code, **kwargs)
#     175 """Construct a Pandas agent from an LLM and dataframe(s).
#     176
#     177 Security Notice:
#    (...)
#     246
#     247 """
#     248 if not allow_dangerous_code:
# --> 249     raise ValueError(
# ...

# %%
agent.run("How many rows in the age column are different")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 agent.run("How many rows in the age column are different")
#
# File c:\Users\samua\anaconda3\envs\tensorflow_env\lib\site-packages\langchain_core\_api\deprecation.py:193, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     191     warned = True
#     192     emit_warning()
# --> 193 return wrapped(*args, **kwargs)
#
# File c:\Users\samua\anaconda3\envs\tensorflow_env\lib\site-packages\langchain\chains\base.py:627, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     625         msg = "`run` supports only one positional argument."
#     626         raise ValueError(msg)
# --> 627     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     628         _output_key
#     629     ]
# ...

# %%
df2=df1.copy()

# %%
df2["Age_Multiplied"]=df1["Age"] * 2

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_Multiplied
# 0      0         A/5 21171   7.2500   NaN        S            44.0
# 1      0          PC 17599  71.2833   C85        C            76.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S            52.0
# ...

# %%
agent = create_pandas_dataframe_agent(
    llm, 
    [df,df1, df2], 
    verbose=True,
    agent_type="openai-tools",
    allow_dangerous_code=True
    )

# %%
agent.run("Are the number of columns same in all the dataframe")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 agent.run("Are the number of columns same in all the dataframe")
#
# File c:\Users\samua\anaconda3\envs\tensorflow_env\lib\site-packages\langchain_core\_api\deprecation.py:193, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     191     warned = True
#     192     emit_warning()
# --> 193 return wrapped(*args, **kwargs)
#
# File c:\Users\samua\anaconda3\envs\tensorflow_env\lib\site-packages\langchain\chains\base.py:627, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     625         msg = "`run` supports only one positional argument."
#     626         raise ValueError(msg)
# --> 627     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     628         _output_key
#     629     ]
# ...
